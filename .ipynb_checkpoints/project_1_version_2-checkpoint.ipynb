# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import pylab, mlab, pyplot
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 3)
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
# reading in a sample week of data 
df = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190907.txt")

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/31/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7183242
# 1  REGULAR  7183258
# 2  REGULAR  7183278
# 3  REGULAR  7183393
# 4  REGULAR  7183572
#
#    EXITS
# 0                                            2433142
# 1                                            2433149
# 2                                            2433176
# 3                                            2433262
# 4                                            2433312

# %% [markdown]
# ## cleaning data:

# %%
# adding column of 'datetime' objects
df["DATETIME"] = pd.to_datetime(df["DATE"] + " " + df["TIME"], format="%m/%d/%Y %H:%M:%S")

# %%
# also replacing DATE column with 'datetime' objects of just date (no time)
# to help with later filtering
df["DATE"] = pd.to_datetime(df["DATE"], format="%m/%d/%Y")
df["TIME"] = pd.to_datetime(df["TIME"])

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7183242
# 1  REGULAR  7183258
# 2  REGULAR  7183278
# 3  REGULAR  7183393
# 4  REGULAR  7183572
#
#    EXITS                                                                 \
# 0                                            2433142
# 1                                            2433149
# 2                                            2433176
# 3                                            2433262
# 4                                            2433312
#
#              DATETIME
# 0 2019-08-31 00:00:00
# 1 2019-08-31 04:00:00
# 2 2019-08-31 08:00:00
# 3 2019-08-31 12:00:00
# 4 2019-08-31 16:00:00

# %%
df.DATE.describe()
# Out:
# count                  197503
# unique                      7
# top       2019-09-04 00:00:00
# freq                    29014
# first     2019-08-31 00:00:00
# last      2019-09-06 00:00:00
# Name: DATE, dtype: object

# %%
# cleaning up column name EXIT which had trailing spaces
# credit to this article (https://towardsdatascience.com/mta-turstile-data-my-first-taste-of-a-data-science-project-493b03f1708a)
# for pointing this out! 
df.rename(columns={'EXITS                                                               ':"EXITS"}, inplace=True)

# %%
# finding actual entries and exits during each time period by finding difference
# in readings, for each turnstile
real_entries = df.groupby(["C/A", "UNIT", "SCP"]).agg({"ENTRIES": "diff"})
real_exits = df.groupby(["C/A", "UNIT", "SCP"]).agg({"EXITS": "diff"})

# %% [markdown]
# the above real entries and exits data was found using the pandas aggregate function "diff". the entries and exists were cumulative outputs for all time, so only the difference between each value and teh value before it would be the entries in that time period. Per documentation of pandas 'diff': "Calculates the difference of a DataFrame element compared with another element in the DataFrame (default is the element in the same column of the previous row)." This is exactly what we wanted to do. We broke it up into each individual unit first, becuase we only want it to subtract from entry/exit data for its own turnstile. therefore, first values for each turnstile, with nothing to subtract from (no preceding value), return NaN.

# %%
# adding actual entries and exits as columns to the DataFrame
df["REAL_ENTRIES"] = real_entries["ENTRIES"]
df["REAL_EXITS"] = real_exits["EXITS"]

# %% [markdown]
# ## exploring data:

# %%
# finding outliers in actual entries and exits
df["REAL_ENTRIES"].sort_values(ascending=False).head(25)
# Out:
# 73163    718560745.0
# 116104       92258.0
# 116895        7625.0
# 116877        7308.0
# 3095          2872.0
# 3089          2746.0
# 3101          2719.0
# 96607         2599.0
# 3173          2598.0
# 3185          2559.0
# 184356        2532.0
# 50270         2520.0
# 3107          2512.0
# 3179          2482.0
# 96613         2479.0
# 3137          2475.0
# 96601         2467.0
# 50276         2454.0
# 50264         2441.0
# 116408        2438.0
# 50318         2403.0
# 1373          2398.0
# 4873          2379.0
# 50312         2372.0
# 4915          2367.0
# Name: REAL_ENTRIES, dtype: float64

# %%
# investigating highest value 
df.loc[73163]
# Out:
# C/A                            N205
# UNIT                           R195
# SCP                        02-00-00
# STATION             161/YANKEE STAD
# LINENAME                        BD4
# DIVISION                        IND
# DATE            2019-09-06 00:00:00
# TIME                       12:22:00
# DESC                        REGULAR
# ENTRIES                   721441289
# EXITS                    1895802233
# DATETIME        2019-09-06 12:22:00
# REAL_ENTRIES            718560745.0
# REAL_EXITS             1886405893.0
# Name: 73163, dtype: object

# %% [markdown]
# even though there is probably a lot of foot traffic near Yankee Stadium,
# over 700 million people in 4 hours is beyond unrealistic
# its exits value is also absurdly high, indicating a malfunction at this time
# deciding to remove this data point.

# %%
# investigating next highest, with 90,000: 
df.loc[116104]
# Out:
# C/A                           PTH03
# UNIT                           R552
# SCP                        00-00-00
# STATION              JOURNAL SQUARE
# LINENAME                          1
# DIVISION                        PTH
# DATE            2019-09-01 00:00:00
# TIME                       15:50:02
# DESC                        REGULAR
# ENTRIES                      126651
# EXITS                        126869
# DATETIME        2019-09-01 15:50:02
# REAL_ENTRIES                92258.0
# REAL_EXITS                 110916.0
# Name: 116104, dtype: object

# %%
df.loc[116895]
# Out:
# C/A                           PTH03
# UNIT                           R552
# SCP                        00-01-08
# STATION              JOURNAL SQUARE
# LINENAME                          1
# DIVISION                        PTH
# DATE            2019-09-06 00:00:00
# TIME                       12:03:31
# DESC                        REGULAR
# ENTRIES                        7626
# EXITS                          6509
# DATETIME        2019-09-06 12:03:31
# REAL_ENTRIES                 7625.0
# REAL_EXITS                   6509.0
# Name: 116895, dtype: object

# %%
df.loc[116877]
# Out:
# C/A                           PTH03
# UNIT                           R552
# SCP                        00-01-08
# STATION              JOURNAL SQUARE
# LINENAME                          1
# DIVISION                        PTH
# DATE            2019-09-03 00:00:00
# TIME                       12:39:31
# DESC                        REGULAR
# ENTRIES                        7309
# EXITS                          6264
# DATETIME        2019-09-03 12:39:31
# REAL_ENTRIES                 7308.0
# REAL_EXITS                   6264.0
# Name: 116877, dtype: object

# %% [markdown]
# all 3 of the above data points are for the same station, with single reading (4 hour) riderships of ~90,000, ~7000 and ~7000 respectively, far above the next highest readings which are all in the range of ~2000. Furthermore, they jump up by this much all at once -- the total entries/exits for that turnstile are equal to the real_entries/real_exits or 4-hour change, hence the turnstile probably reset just before that. These data points should also be eliminated.

# %%
df.loc[3090:3100]
# Out:
#        C/A  UNIT       SCP          STATION  LINENAME DIVISION       DATE  \
# 3090  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3091  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3092  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3093  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3094  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3095  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-04
# 3096  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-05
# 3097  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-05
# 3098  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-05
# 3099  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-05
# 3100  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT 2019-09-05
#
#                     TIME     DESC   ENTRIES     EXITS            DATETIME  \
# 3090 2020-07-02 00:00:00  REGULAR  27551050  11443153 2019-09-04 00:00:00
# 3091 2020-07-02 04:00:00  REGULAR  27551228  11443196 2019-09-04 04:00:00
# 3092 2020-07-02 08:00:00  REGULAR  27551499  11443479 2019-09-04 08:00:00
# 3093 2020-07-02 12:00:00  REGULAR  27552544  11444532 2019-09-04 12:00:00
# 3094 2020-07-02 16:00:00  REGULAR  27553826  11445197 2019-09-04 16:00:00
# 3095 2020-07-02 20:00:00  REGULAR  27556698  11445624 2019-09-04 20:00:00
# 3096 2020-07-02 00:00:00  REGULAR  27557702  11445847 2019-09-05 00:00:00
# 3097 2020-07-02 04:00:00  REGULAR  27557866  11445868 2019-09-05 04:00:00
# 3098 2020-07-02 08:00:00  REGULAR  27558132  11446122 2019-09-05 08:00:00
# 3099 2020-07-02 12:00:00  REGULAR  27559190  11447157 2019-09-05 12:00:00
# 3100 2020-07-02 16:00:00  REGULAR  27560559  11447841 2019-09-05 16:00:00
#
#       REAL_ENTRIES  REAL_EXITS
# 3090        1045.0       215.0
# 3091         178.0        43.0
# 3092         271.0       283.0
# 3093        1045.0      1053.0
# 3094        1282.0       665.0
# 3095        2872.0       427.0
# 3096        1004.0       223.0
# 3097         164.0        21.0
# 3098         266.0       254.0
# 3099        1058.0      1035.0
# 3100        1369.0       684.0

# %%
df["REAL_EXITS"].sort_values(ascending=False).head(25)
# Out:
# 73163    1886405893.0
# 116104       110916.0
# 116895         6509.0
# 116877         6264.0
# 97422          5598.0
# 52968          4876.0
# 53010          4477.0
# 52950          4263.0
# 52962          4218.0
# 52956          4203.0
# 125525         4019.0
# 125536         3907.0
# 159575         3813.0
# 52998          3772.0
# 52992          3691.0
# 53004          3565.0
# 159574         3506.0
# 116569         3348.0
# 98533          3280.0
# 53052          3242.0
# 159029         3215.0
# 76941          3210.0
# 195022         3161.0
# 195034         3152.0
# 195016         3151.0
# Name: REAL_EXITS, dtype: float64

# %% [markdown]
# the rows with highest exits are the same as those with highest entries above. the first 2 definitely seem anomalous. However, here the next 2 (row 116895 and 116877) are not far off from the rest of the data at all.. Looking at rows before and after the 2nd highest value (row 116104):

# %%
df.loc[116103:116105]
# Out:
#           C/A  UNIT       SCP         STATION LINENAME DIVISION       DATE  \
# 116103  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116104  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116105  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
#
#             TIME     DESC  ENTRIES   EXITS            DATETIME  REAL_ENTRIES  \
# 116103  13:05:39  REGULAR    34393   15953 2019-09-01 13:05:39          73.0
# 116104  15:50:02  REGULAR   126651  126869 2019-09-01 15:50:02       92258.0
# 116105  17:17:39  REGULAR    34450   15975 2019-09-01 17:17:39      -92201.0
#
#         REAL_EXITS
# 116103        17.0
# 116104    110916.0
# 116105   -110894.0

# %% [markdown]
# it's clear that 116104 should be removed, as it causes the next entry to dip into the negative which is impossible. obviously negative data points will need to be removed but more on that later.
#
# looking at rows surrounding 3rd highest (row 116895):

# %%
df.loc[116894:116896]
# Out:
#           C/A  UNIT       SCP         STATION LINENAME DIVISION       DATE  \
# 116894  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH 2019-09-06
# 116895  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH 2019-09-06
# 116896  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH 2019-09-06
#
#             TIME     DESC  ENTRIES  EXITS            DATETIME  REAL_ENTRIES  \
# 116894  09:36:51  REGULAR        1      0 2019-09-06 09:36:51       -7577.0
# 116895  12:03:31  REGULAR     7626   6509 2019-09-06 12:03:31        7625.0
# 116896  16:15:31  REGULAR     7639   6536 2019-09-06 16:15:31          13.0
#
#         REAL_EXITS
# 116894     -6487.0
# 116895      6509.0
# 116896        27.0

# %% [markdown]
# so, this indicates that the high reading of ~7000 at row 116895 was only because the row that preceded it was negative. hence it actually should also be removed.

# %%
df[df["STATION"] == "JOURNAL SQUARE"].head(100)
# Out:
#           C/A  UNIT       SCP         STATION LINENAME DIVISION       DATE  \
# 116095  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-08-31
# 116096  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-08-31
# 116097  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-08-31
# 116098  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-08-31
# 116099  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-08-31
# 116100  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116101  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116102  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116103  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116104  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116105  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116106  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-01
# 116107  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116108  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116109  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116110  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116111  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116112  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-02
# 116113  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116114  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116115  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116116  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116117  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116118  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-03
# 116119  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-04
# 116120  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-04
# 116121  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-04
# 116122  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-04
# 116123  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-04
# 116124  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116125  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116126  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116127  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116128  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116129  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-05
# 116130  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116131  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116132  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116133  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116134  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116135  PTH03  R552  00-00-00  JOURNAL SQUARE        1      PTH 2019-09-06
# 116136  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116137  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116138  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116139  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116140  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116141  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-08-31
# 116142  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116143  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116144  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116145  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116146  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116147  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-01
# 116148  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-02
# 116149  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-02
# 116150  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-02
# 116151  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-02
# 116152  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-02
# 116153  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116154  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116155  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116156  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116157  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116158  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-03
# 116159  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116160  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116161  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116162  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116163  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116164  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-04
# 116165  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116166  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116167  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116168  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116169  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116170  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-05
# 116171  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-06
# 116172  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-06
# 116173  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-06
# 116174  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-06
# 116175  PTH03  R552  00-00-01  JOURNAL SQUARE        1      PTH 2019-09-06
# 116176  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116177  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116178  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116179  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116180  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116181  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-08-31
# 116182  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-01
# 116183  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-01
# 116184  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-01
# 116185  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-01
# 116186  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-01
# 116187  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116188  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116189  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116190  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116191  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116192  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-02
# 116193  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-03
# 116194  PTH03  R552  00-00-02  JOURNAL SQUARE        1      PTH 2019-09-03
#
#             TIME     DESC  ENTRIES   EXITS            DATETIME  REAL_ENTRIES  \
# 116095  03:29:39  REGULAR    34042   15843 2019-08-31 03:29:39           nan
# 116096  07:41:39  REGULAR    34062   15866 2019-08-31 07:41:39          20.0
# 116097  11:53:39  REGULAR    34132   15886 2019-08-31 11:53:39          70.0
# 116098  16:05:39  REGULAR    34217   15904 2019-08-31 16:05:39          85.0
# 116099  20:17:39  REGULAR    34279   15916 2019-08-31 20:17:39          62.0
# 116100  00:29:39  REGULAR    34298   15925 2019-09-01 00:29:39          19.0
# 116101  04:41:39  REGULAR    34298   15929 2019-09-01 04:41:39           0.0
# 116102  08:53:39  REGULAR    34320   15936 2019-09-01 08:53:39          22.0
# 116103  13:05:39  REGULAR    34393   15953 2019-09-01 13:05:39          73.0
# 116182  03:42:40  REGULAR    72912   27601 2019-09-01 03:42:40           8.0
# 116183  07:54:40  REGULAR    72959   27627 2019-09-01 07:54:40          47.0
# 116184  12:06:40  REGULAR    73140   27648 2019-09-01 12:06:40         181.0
# 116185  16:18:40  REGULAR    73348   27680 2019-09-01 16:18:40         208.0
# 116186  20:30:40  REGULAR    73464   27697 2019-09-01 20:30:40         116.0
# 116187  00:42:40  REGULAR    73504   27750 2019-09-02 00:42:40          40.0
# 116188  05:08:40  REGULAR    73513   27799 2019-09-02 05:08:40           9.0
# 116189  09:20:40  REGULAR    73593   27810 2019-09-02 09:20:40          80.0
# 116190  13:32:40  REGULAR    73714   27815 2019-09-02 13:32:40         121.0
# 116191  17:44:40  REGULAR    73843   27833 2019-09-02 17:44:40         129.0
# 116192  21:56:40  REGULAR    73914   27879 2019-09-02 21:56:40          71.0
# 116193  02:08:40  REGULAR    73931   27919 2019-09-03 02:08:40          17.0
# 116194  06:20:40  REGULAR    73987   27936 2019-09-03 06:20:40          56.0
#
#         REAL_EXITS
# 116095         nan
# 116096        23.0
# 116097        20.0
# 116098        18.0
# 116099        12.0
# 116100         9.0
# 116101         4.0
# 116102         7.0
# 116103        17.0
# 116104    110916.0
# 116105   -110894.0
# 116106        15.0
# 116107        24.0
# 116108         6.0
# 116109         3.0
# 116110         9.0
# 116111        13.0
# 116112         8.0
# 116113        12.0
# 116114         9.0
# 116115        20.0
# 116116        39.0
# 116117        34.0
# 116118        23.0
# 116119        14.0
# 116120        15.0
# 116121        16.0
# 116122        15.0
# 116123        22.0
# 116124        14.0
# 116125        11.0
# 116126        19.0
# 116127        15.0
# 116128        57.0
# 116129        56.0
# 116130        28.0
# 116131        15.0
# 116132        19.0
# 116133        20.0
# 116134        96.0
# 116135        26.0
# 116136         nan
# 116137        81.0
# 116138        12.0
# 116139        11.0
# 116140        15.0
# 116141        17.0
# 116142        10.0
# 116143        22.0
# 116144        12.0
# 116145        30.0
# 116146        15.0
# 116147        12.0
# 116148        69.0
# 116149        12.0
# 116150         4.0
# 116151         5.0
# 116152        19.0
# 116153         9.0
# 116154        19.0
# 116155         8.0
# 116156        22.0
# 116157        85.0
# 116158        50.0
# 116159        51.0
# 116160        16.0
# 116161        12.0
# 116162         9.0
# 116163        30.0
# 116164        31.0
# 116165        48.0
# 116166        13.0
# 116167         8.0
# 116168        21.0
# 116169       166.0
# 116170        83.0
# 116171        62.0
# 116172         9.0
# 116173        13.0
# 116174        63.0
# 116175       116.0
# 116176         nan
# 116177        58.0
# 116178        17.0
# 116179        23.0
# 116180        37.0
# 116181        13.0
# 116182        20.0
# 116183        26.0
# 116184        21.0
# 116185        32.0
# 116186        17.0
# 116187        53.0
# 116188        49.0
# 116189        11.0
# 116190         5.0
# 116191        18.0
# 116192        46.0
# 116193        40.0
# 116194        17.0

# %% [markdown]
# looking at general ridership for Journal Square, it is a station with very low ridership, numbers usually not exceeding the double digits. the values of 7000 must be deleted.

# %% [markdown]
# as a rule, then, based on the last several test cases, even if data looks to fall within a normal range at first glance, it may be anomolous for it's stations normal values and caused only by a turnstile reset/error. The context that comes from looking at surrounding data points makes this clear.

# %% [markdown]
# one solution could be to remove negative data points, and then remove the two adjacent entries. as shown in the two above examples, sometimes a negative value can be predeced by a super high value that caused its error, or sometimes it can cause a super high value after it because it itself is the error or was caused by a turnstile reset. deleting all 3 points could be a reasonable move just to account for all possible cases. the amount of data lost will be insignificant when compared to how drastically the error values would offset the means.

# %%
# checking out the next highest exits value after Journal Square
df.loc[97422]
# Out:
# C/A                            N505
# UNIT                           R022
# SCP                        02-00-02
# STATION             34 ST-HERALD SQ
# LINENAME                   BDFMNQRW
# DIVISION                        IND
# DATE            2019-09-06 00:00:00
# TIME                       16:00:00
# DESC                        REGULAR
# ENTRIES                     7515309
# EXITS                       3880256
# DATETIME        2019-09-06 16:00:00
# REAL_ENTRIES                  503.0
# REAL_EXITS                   5598.0
# Name: 97422, dtype: object

# %%
# checking out adjacent data points
df.loc[97419:97430]
# Out:
#         C/A  UNIT       SCP          STATION  LINENAME DIVISION       DATE  \
# 97419  N505  R022  02-00-02  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-01
# 97420  N505  R022  02-00-02  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-01
# 97421  N505  R022  02-00-02  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-01
# 97422  N505  R022  02-00-02  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-06
# 97423  N505  R022  02-00-02  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-06
# 97425  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-08-31
# 97426  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-08-31
# 97427  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-08-31
# 97428  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-08-31
# 97429  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-08-31
# 97430  N505  R022  02-00-03  34 ST-HERALD SQ  BDFMNQRW      IND 2019-09-01
#
#                      TIME     DESC  ENTRIES    EXITS            DATETIME  \
# 97419 2020-07-02 08:00:00  REGULAR  7514488  3874395 2019-09-01 08:00:00
# 97420 2020-07-02 12:00:00  REGULAR  7514641  3874506 2019-09-01 12:00:00
# 97421 2020-07-02 16:00:00  REGULAR  7514806  3874658 2019-09-01 16:00:00
# 97422 2020-07-02 16:00:00  REGULAR  7515309  3880256 2019-09-06 16:00:00
# 97423 2020-07-02 20:00:00  REGULAR  7516273  3880501 2019-09-06 20:00:00
# 97425 2020-07-02 04:00:00  REGULAR  9247782  5598931 2019-08-31 04:00:00
# 97426 2020-07-02 08:00:00  REGULAR  9247798  5598968 2019-08-31 08:00:00
# 97427 2020-07-02 12:00:00  REGULAR  9247904  5599093 2019-08-31 12:00:00
# 97428 2020-07-02 16:00:00  REGULAR  9248074  5599241 2019-08-31 16:00:00
# 97429 2020-07-02 20:00:00  REGULAR  9248260  5599394 2019-08-31 20:00:00
# 97430 2020-07-02 00:00:00  REGULAR  9248457  5599486 2019-09-01 00:00:00
#
#        REAL_ENTRIES  REAL_EXITS
# 97419          28.0        29.0
# 97420         153.0       111.0
# 97421         165.0       152.0
# 97422         503.0      5598.0
# 97423         964.0       245.0
# 97425          54.0        16.0
# 97426          16.0        37.0
# 97427         106.0       125.0
# 97428         170.0       148.0
# 97429         186.0       153.0
# 97430         197.0        92.0

# %% [markdown]
# So, ~5000 is high for this station, but not super (orders of magnitude) far off from its regular ridership which gets up into the thousands. It is not preceded or followed by any negative values or obvious errors, and the entry data given by the turnstile at the same time was a normal value. So, I'd make the case to leave this data point alone. Furthermore, 34th st herald sq station is right by the Empire State Buildling, so it could definitely see random surges is ridership based on tourism or events

# %% [markdown]
# most of the rest of the highest points in the highest value list after this one are for 42nd st-Port Auth station:

# %%
df.loc[52965:52970] #42nd st-port auth station high exits
# Out:
#          C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 52965  N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 52966  N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 52967  N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 52968  N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 52970  N063A  R011  00-00-01  42 ST-PORT AUTH  ACENQRS1237W      IND
#
#             DATE                TIME     DESC     ENTRIES      EXITS  \
# 52965 2019-09-06 2020-07-02 08:00:00  REGULAR     1580122    6398117
# 52966 2019-09-06 2020-07-02 12:00:00  REGULAR     1580692    6400692
# 52967 2019-09-06 2020-07-02 16:00:00  REGULAR     1580909    6403057
# 52968 2019-09-06 2020-07-02 20:00:00  REGULAR     1581034    6407933
# 52970 2019-08-31 2020-07-02 04:00:00  REGULAR  1280371484  176804539
#
#                  DATETIME  REAL_ENTRIES  REAL_EXITS
# 52965 2019-09-06 08:00:00         560.0      1329.0
# 52966 2019-09-06 12:00:00         570.0      2575.0
# 52967 2019-09-06 16:00:00         217.0      2365.0
# 52968 2019-09-06 20:00:00         125.0      4876.0
# 52970 2019-08-31 04:00:00          67.0       227.0

# %% [markdown]
# Looking it up: 42nd/port-auth is right next to Times Square! So that makes sense.

# %%
# checking out lowest data points: 
df["REAL_ENTRIES"].sort_values().head(25), df["REAL_EXITS"].sort_values().head(25)
# Out:
# (193155   -12409434.0
#  193323    -8327252.0
#  20539     -6346214.0
#  193407    -5369163.0
#  81155     -4584498.0
#  19507     -1599300.0
#  36983      -480406.0
#  101571     -350664.0
#  46403      -202825.0
#  65480      -101194.0
#  116105      -92201.0
#  37108       -86120.0
#  37006       -74424.0
#  122458      -66281.0
#  71539       -61315.0
#  131361      -41994.0
#  15624       -36550.0
#  120801      -18344.0
#  121523       -9925.0
#  125926       -8925.0
#  141693       -7688.0
#  116894       -7577.0
#  116876       -7271.0
#  11542        -1665.0
#  11530        -1651.0
#  Name: REAL_ENTRIES, dtype: float64,
#  193407   -14768030.0
#  193155    -9983375.0
#  193323    -8464033.0
#  81155     -1161890.0
#  19507     -1109372.0
#  20539     -1010106.0
#  46403      -421614.0
#  15624      -251664.0
#  101571     -242022.0
#  36983      -141218.0
#  71539      -137066.0
#  131361     -129645.0
#  37108      -114594.0
#  116105     -110894.0
#  122458      -35934.0
#  65480       -21533.0
#  37006       -15190.0
#  141693      -13386.0
#  125926      -10000.0
#  116894       -6487.0
#  116876       -6234.0
#  158959       -2758.0
#  158957       -2732.0
#  158951       -2719.0
#  158963       -2669.0
#  Name: REAL_EXITS, dtype: float64)

# %% [markdown]
# negative data points need to be deleted, as well as the row that immediately precedes and immediately follows each.

# %% [markdown]
# ## filtering data:

# %% [markdown]
# to mitigate error, we have chosen to simply delete rows with erroneous either entry or exit data, as well as the surrounding 2 rows, one of which will also hold erroneous data. given that the scope of data we are looking at is sum of ridership over 3 months, the effect of losing these occasional entries is minute.

# %%
# removing negative values, and adjacent entries: 

neg_entries = df[df["REAL_ENTRIES"] < 0]
neg_entries.shape
# Out:
# (1853, 14)

# %%
nan_entries = df[df["REAL_ENTRIES"].isna()]
nan_entries.shape
# Out:
# (4893, 14)

# %%
neg_exits = df[df["REAL_EXITS"] < 0]
neg_exits.shape
# Out:
# (1399, 14)

# %%
nan_exits = df[df["REAL_EXITS"].isna()]
nan_exits.shape
# Out:
# (4893, 14)

# %%
neg_both = df[(df["REAL_ENTRIES"] < 0) & (df["REAL_EXITS"] < 0)]
neg_both.shape
# Out:
# (853, 14)

# %%
df.shape
# Out:
# (204795, 14)

# %% [markdown]
# Maximum total number of rows that will deleted by removing those with negative values + 2 adjacents = 1853 + 1399 - 853 = 2399 * 3 = 7197. That's assuming none of the adjacent rows are themselves negative (which many are) which would yield a lower number. 7197 / 204795 = 3.5 % of data lost..

# %%
neg_entries["STATION"].unique(), neg_exits["STATION"].unique()
# Out:
# (array(['57 ST-7 AV', '34 ST-HERALD SQ', 'CORTLANDT ST', 'CANAL ST',
#         'AVENUE H', 'BOROUGH HALL', 'DEKALB AV', 'BAY PKWY', '6 AV',
#         'JFK JAMAICA CT1', '104 ST', 'METROPOLITAN AV', '190 ST', '135 ST',
#         '42 ST-PORT AUTH', '14 ST', 'LAFAYETTE AV', 'KINGSTON-THROOP',
#         'BEACH 44 ST', '161/YANKEE STAD', '167 ST', '182-183 STS',
#         'LEXINGTON AV/53', '46 ST', 'ELMHURST AV', 'GRAND-NEWTOWN',
#         'JAMAICA 179 ST', 'COURT SQ', '23 ST', 'GRAND ST', 'AVENUE U',
#         'LEXINGTON AV/63', 'JAMAICA CENTER', 'JOURNAL SQUARE',
#         'TWENTY THIRD ST', 'THIRTY ST', 'LACKAWANNA', 'PATH NEW WTC',
#         'FULTON ST', '34 ST-PENN STA', 'TIMES SQ-42 ST', '72 ST', '33 ST',
#         'GRD CNTRL-42 ST', '59 ST', '125 ST', '174 ST', '3 AV 138 ST',
#         'HUNTS POINT AV', 'WHITLOCK AV', '61 ST WOODSIDE', 'FRANKLIN AV',
#         'FLATBUSH AV-B.C', 'EASTCHSTER/DYRE'], dtype=object),
#  array(['57 ST-7 AV', 'PROSPECT PARK', 'AVENUE H', 'KINGS HWY',
#         'BOROUGH HALL', 'DEKALB AV', '18 AV', 'BAY PKWY', '6 AV',
#         'JFK JAMAICA CT1', '104 ST', 'METROPOLITAN AV', '190 ST', '135 ST',
#         '42 ST-PORT AUTH', '14 ST', 'HIGH ST', 'KINGSTON-THROOP',
#         'BEACH 44 ST', '161/YANKEE STAD', '46 ST', 'ELMHURST AV',
#         'GRAND-NEWTOWN', '75 AV', 'COURT SQ', 'GRAND ST', 'AVENUE I',
#         'LEXINGTON AV/63', 'JOURNAL SQUARE', 'TWENTY THIRD ST',
#         'THIRTY ST', 'LACKAWANNA', 'PATH NEW WTC', 'FULTON ST',
#         '34 ST-PENN STA', '72 ST', '33 ST', 'GRD CNTRL-42 ST', '59 ST',
#         '86 ST', '174 ST', 'GUN HILL RD', '225 ST', '3 AV 138 ST',
#         '61 ST WOODSIDE', 'FRANKLIN AV', 'FLATBUSH AV-B.C'], dtype=object))

# %%
# looking at why a randomly chosen negative value (row 11530) may be negative
df.loc[11528:11533]
# Out:
#         C/A  UNIT       SCP   STATION LINENAME DIVISION       DATE      TIME  \
# 11528  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-03  13:00:00
# 11529  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-03  17:00:00
# 11530  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-03  21:00:00
# 11531  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-04  01:00:00
# 11532  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-04  05:00:00
# 11533  A066  R118  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-09-04  09:00:00
#
#           DESC     ENTRIES       EXITS            DATETIME  REAL_ENTRIES  \
# 11528  REGULAR  1723571535  1763170239 2019-09-03 13:00:00        -491.0
# 11529  REGULAR  1723570355  1763170472 2019-09-03 17:00:00       -1180.0
# 11530  REGULAR  1723568704  1763170753 2019-09-03 21:00:00       -1651.0
# 11531  REGULAR  1723568326  1763170882 2019-09-04 01:00:00        -378.0
# 11532  REGULAR  1723568304  1763170895 2019-09-04 05:00:00         -22.0
# 11533  REGULAR  1723568195  1763171129 2019-09-04 09:00:00        -109.0
#
#        REAL_EXITS
# 11528       325.0
# 11529       233.0
# 11530       281.0
# 11531       129.0
# 11532        13.0
# 11533       234.0

# %%
# hmm several of station "CANAL ST" are negative? 
canal = df[df["STATION"] == "CANAL ST"]
canal
# Out:
#          C/A  UNIT       SCP   STATION LINENAME DIVISION       DATE      TIME  \
# 6737    A043  R462  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-08-31  01:00:00
# 6738    A043  R462  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-08-31  05:00:00
# 6739    A043  R462  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-08-31  09:00:00
# 6740    A043  R462  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-08-31  13:00:00
# 6741    A043  R462  00-00-00  CANAL ST  JNQRZ6W      BMT 2019-08-31  17:00:00
# ...      ...   ...       ...       ...      ...      ...        ...       ...
# 133080  R120  R320  01-00-02  CANAL ST        1      IRT 2019-09-06  05:00:00
# 133081  R120  R320  01-00-02  CANAL ST        1      IRT 2019-09-06  09:00:00
# 133082  R120  R320  01-00-02  CANAL ST        1      IRT 2019-09-06  13:00:00
# 133083  R120  R320  01-00-02  CANAL ST        1      IRT 2019-09-06  17:00:00
# 133084  R120  R320  01-00-02  CANAL ST        1      IRT 2019-09-06  21:00:00
#
#            DESC    ENTRIES      EXITS            DATETIME  REAL_ENTRIES  \
# 6737    REGULAR  371370779  456070130 2019-08-31 01:00:00           nan
# 6738    REGULAR  371370810  456070136 2019-08-31 05:00:00          31.0
# 6739    REGULAR  371370854  456070308 2019-08-31 09:00:00          44.0
# 6740    REGULAR  371371072  456071081 2019-08-31 13:00:00         218.0
# 6741    REGULAR  371371709  456072138 2019-08-31 17:00:00         637.0
# ...         ...        ...        ...                 ...           ...
# 133080  REGULAR    1421028    8068916 2019-09-06 05:00:00           0.0
# 133081  REGULAR    1421049    8069278 2019-09-06 09:00:00          21.0
# 133082  REGULAR    1421096    8069769 2019-09-06 13:00:00          47.0
# 133083  REGULAR    1421248    8070022 2019-09-06 17:00:00         152.0
# 133084  REGULAR    1421407    8070184 2019-09-06 21:00:00         159.0
#
#         REAL_EXITS
# 6737           nan
# 6738           6.0
# 6739         172.0
# 6740         773.0
# 6741        1057.0
# ...            ...
# 133080         5.0
# 133081       362.0
# 133082       491.0
# 133083       253.0
# 133084       162.0
#
# [2429 rows x 14 columns]

# %%
canal["REAL_ENTRIES"].sort_values().head(50)
# Out:
# 11542   -1665.0
# 11530   -1651.0
# 11536   -1551.0
# 11548   -1540.0
# 11547   -1225.0
# 11529   -1180.0
# 11541   -1162.0
# 11535   -1063.0
# 11512    -940.0
# 11517    -886.0
# 11511    -866.0
# 11518    -795.0
# 11524    -750.0
# 11523    -614.0
# 11534    -511.0
# 11540    -510.0
# 11546    -505.0
# 11528    -491.0
# 11513    -456.0
# 11543    -452.0
# 11519    -395.0
# 11537    -394.0
# 11510    -383.0
# 11531    -378.0
# 11516    -331.0
# 11522    -299.0
# 11525    -293.0
# 11545    -115.0
# 11539    -114.0
# 11533    -109.0
# 11527    -102.0
# 11521     -61.0
# 11509     -61.0
# 11508     -47.0
# 11544     -43.0
# 11515     -41.0
# 11514     -37.0
# 11520     -25.0
# 11532     -22.0
# 11538     -20.0
# 11526     -18.0
# 7510        0.0
# 7032        0.0
# 7511        0.0
# 58663       0.0
# 7033        0.0
# 7035        0.0
# 7512        0.0
# 7026        0.0
# 58669       0.0
# Name: REAL_ENTRIES, dtype: float64

# %%
# deleting both negative and NaN values of entries
df_deleted_entries = df.loc[df["REAL_ENTRIES"] >= 0]
df_deleted_entries.head(50)

# deletes row 42 which is the first known NaN value -- i.e. working correctly!
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  08:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  20:00:00
# 18  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  00:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  04:00:00
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  08:00:00
# 21  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  12:00:00
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  16:00:00
# 23  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  20:00:00
# 24  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  00:00:00
# 25  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  04:00:00
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  08:00:00
# 27  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  12:00:00
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  16:00:00
# 29  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  20:00:00
# 30  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  00:00:00
# 31  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  04:00:00
# 32  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  08:00:00
# 33  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  12:00:00
# 34  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  16:00:00
# 35  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  20:00:00
# 36  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  00:00:00
# 37  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  04:00:00
# 38  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  08:00:00
# 39  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  12:00:00
# 40  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  16:00:00
# 41  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  20:00:00
# 43  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 44  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 45  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 46  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  16:00:00
# 47  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  20:00:00
# 48  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  00:00:00
# 49  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  04:00:00
# 50  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  08:00:00
# 51  A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  12:00:00
#
#        DESC  ENTRIES    EXITS            DATETIME  REAL_ENTRIES  REAL_EXITS
# 1   REGULAR  7183258  2433149 2019-08-31 04:00:00          16.0         7.0
# 2   REGULAR  7183278  2433176 2019-08-31 08:00:00          20.0        27.0
# 3   REGULAR  7183393  2433262 2019-08-31 12:00:00         115.0        86.0
# 4   REGULAR  7183572  2433312 2019-08-31 16:00:00         179.0        50.0
# 46  REGULAR  6392586  1434841 2019-08-31 16:00:00         147.0        25.0
# 47  REGULAR  6392752  1434877 2019-08-31 20:00:00         166.0        36.0
# 48  REGULAR  6392863  1434893 2019-09-01 00:00:00         111.0        16.0
# 49  REGULAR  6392878  1434899 2019-09-01 04:00:00          15.0         6.0
# 50  REGULAR  6392891  1434910 2019-09-01 08:00:00          13.0        11.0
# 51  REGULAR  6392996  1434934 2019-09-01 12:00:00         105.0        24.0

# %%
# deleting both negative and NaN values of exits from the already entry-filtered dataset above
df_filtered = df_deleted_entries.loc[df["REAL_EXITS"] >= 0]
df_filtered.shape
# Out:
# (197503, 14)

# %%
df_filtered.head(100)
# Out:
#       C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 2    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 3    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 4    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  16:00:00
# 5    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31  20:00:00
# 6    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  00:00:00
# 7    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  04:00:00
# 8    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  08:00:00
# 9    A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  12:00:00
# 10   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  16:00:00
# 11   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-01  20:00:00
# 12   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  00:00:00
# 13   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  04:00:00
# 14   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  08:00:00
# 15   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  12:00:00
# 16   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  16:00:00
# 17   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-02  20:00:00
# 18   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  00:00:00
# 19   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  04:00:00
# 20   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  08:00:00
# 21   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  12:00:00
# 22   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  16:00:00
# 23   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-03  20:00:00
# 24   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  00:00:00
# 25   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  04:00:00
# 26   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  08:00:00
# 27   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  12:00:00
# 28   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  16:00:00
# 29   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-04  20:00:00
# 30   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  00:00:00
# 31   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  04:00:00
# 32   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  08:00:00
# 33   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  12:00:00
# 34   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  16:00:00
# 35   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-05  20:00:00
# 36   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  00:00:00
# 37   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  04:00:00
# 38   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  08:00:00
# 39   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  12:00:00
# 40   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  16:00:00
# 41   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-09-06  20:00:00
# 43   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 44   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 45   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 46   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  16:00:00
# 47   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-08-31  20:00:00
# 48   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  00:00:00
# 49   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  04:00:00
# 50   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  08:00:00
# 51   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  12:00:00
# 52   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  16:00:00
# 53   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-01  20:00:00
# 54   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  00:00:00
# 55   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  04:00:00
# 56   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  08:00:00
# 57   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  12:00:00
# 58   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  16:00:00
# 59   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-02  20:00:00
# 60   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  00:00:00
# 61   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  04:00:00
# 62   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  08:00:00
# 63   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  12:00:00
# 64   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  16:00:00
# 65   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-03  20:00:00
# 66   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  00:00:00
# 67   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  04:00:00
# 68   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  08:00:00
# 69   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  12:00:00
# 70   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  16:00:00
# 71   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-04  20:00:00
# 72   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  00:00:00
# 73   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  04:00:00
# 74   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  08:00:00
# 75   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  12:00:00
# 76   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  16:00:00
# 77   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-05  20:00:00
# 78   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  00:00:00
# 79   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  04:00:00
# 80   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  08:00:00
# 81   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  12:00:00
# 82   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  16:00:00
# 83   A002  R051  02-00-01   59 ST  NQR456W      BMT 2019-09-06  20:00:00
# 85   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-08-31  04:00:00
# 86   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-08-31  08:00:00
# 87   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-08-31  12:00:00
# 88   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-08-31  16:00:00
# 89   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-08-31  20:00:00
# 90   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-09-01  00:00:00
# 91   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-09-01  04:00:00
# 92   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-09-01  08:00:00
# 93   A002  R051  02-03-00   59 ST  NQR456W      BMT 2019-09
# 76   REGULAR  6396596  1435781 2019-09-05 16:00:00         225.0        35.0
# 77   REGULAR  6397098  1435833 2019-09-05 20:00:00         502.0        52.0
# 78   REGULAR  6397241  1435853 2019-09-06 00:00:00         143.0        20.0
# 79   REGULAR  6397254  1435863 2019-09-06 04:00:00          13.0        10.0
# 80   REGULAR  6397275  1435915 2019-09-06 08:00:00          21.0        52.0
# 81   REGULAR  6397401  1436029 2019-09-06 12:00:00         126.0       114.0
# 82   REGULAR  6397665  1436077 2019-09-06 16:00:00         264.0        48.0
# 83   REGULAR  6398187  1436127 2019-09-06 20:00:00         522.0        50.0
# 85   REGULAR  1280247  4815169 2019-08-31 04:00:00          10.0        14.0
# 86   REGULAR  1280248  4815241 2019-08-31 08:00:00           1.0        72.0
# 87   REGULAR  1280314  4815556 2019-08-31 12:00:00          66.0       315.0
# 88   REGULAR  1280420  4815858 2019-08-31 16:00:00         106.0       302.0
# 89   REGULAR  1280502  4816187 2019-08-31 20:00:00          82.0       329.0
# 90   REGULAR  1280546  4816315 2019-09-01 00:00:00          44.0       128.0
# 91   REGULAR  1280548  4816331 2019-09-01 04:00:00           2.0        16.0
# 92   REGULAR  1280553  4816375 2019-09-01 08:00:00           5.0        44.0
# 93   REGULAR  1280604  4816550 2019-09-01 12:00:00          51.0       175.0
# 94   REGULAR  1280703  4816799 2019-09-01 16:00:00          99.0       249.0
# 95   REGULAR  1280835  4817026 2019-09-01 20:00:00         132.0       227.0
# 96   REGULAR  1280891  4817146 2019-09-02 00:00:00          56.0       120.0
# 97   REGULAR  1280896  4817164 2019-09-02 04:00:00           5.0        18.0
# 98   REGULAR  1280903  4817230 2019-09-02 08:00:00           7.0        66.0
# 99   REGULAR  1280951  4817493 2019-09-02 12:00:00          48.0       263.0
# 100  REGULAR  1281034  4817741 2019-09-02 16:00:00          83.0       248.0
# 101  REGULAR  1281112  4817975 2019-09-02 20:00:00          78.0       234.0
# 102  REGULAR  1281170  4818066 2019-09-03 00:00:00          58.0        91.0

# %% [markdown]
# the above calculations removed negative and NaN values, however as outlined above, we want to remove not only those, but the rows which immediately precede and follow it.

# %%
# finding indexes where there are negative entry values
mask = (df["REAL_ENTRIES"] < 0)

# %%
mask.value_counts()
# Out:
# False    202942
# True       1853
# Name: REAL_ENTRIES, dtype: int64

# %%
list_of_neg_indexes = []
for i, j in enumerate(mask): 
    if j:
        list_of_neg_indexes.append(i)
len(list_of_neg_indexes) # correct length
# Out:
# 1853

# %%
index_array = np.array(list_of_neg_indexes)
index_array
# Out:
# array([  1597,   1598,   1599, ..., 154415, 159696, 168405])

# %%
# df2 = df with negatives and adjacent values removed (still has NaN!)
df2 = df.iloc[list_of_neg_indexes]

# %%
df2.tail(100)
# Out:
#           C/A  UNIT       SCP          STATION   LINENAME DIVISION       DATE  \
# 129161   R107  R305  00-00-02    WTC-CORTLANDT          1      IRT 2019-09-03
# 154419   R221  R170  01-06-02   14 ST-UNION SQ   456LNQRW      IRT 2019-09-06
# 159700   R240  R047  00-03-03  GRD CNTRL-42 ST      4567S      IRT 2019-09-03
# 168409   R286  R309  00-00-03           176 ST          4      IRT 2019-09-02
# 184106   R513  R093  00-00-01            30 AV        NQW      BMT 2019-09-01
# 190955   R533  R055  00-03-00    FLUSHING-MAIN          7      IRT 2019-09-04
# 195104   R610  R057  00-03-02   ATL AV-BARCLAY  2345BDNQR      IRT 2019-09-04
# 199708   R633  R068  00-00-00    VAN SICLEN AV          3      IRT 2019-09-01
# 204191   S102  R165  00-03-00    TOMPKINSVILLE          1      SRT 2019-09-04
# 6635     A042  R086  01-00-02        PRINCE ST        NRW      BMT 2019-09-04
# 13423    B004  R171  00-00-03             7 AV         BQ      BMT 2019-09-01
# 17306    B024  R211  00-00-03        KINGS HWY         BQ      BMT 2019-09-06
# 24519    D001  R390  01-00-00             8 AV          N      BMT 2019-09-02
# 29247    E014  R374  00-00-03         BAY PKWY          D      BMT 2019-08-31
# 39035    J007  R377  00-06-01      FLUSHING AV         JM      BMT 2019-09-03
# 50895    N057  R188  00-00-01            50 ST         CE      IND 2019-09-04
# 61858    N098  R028  00-02-01        FULTON ST   2345ACJZ      IND 2019-09-04
# 75996    N223  R156  01-05-00  BEDFORD PK BLVD         BD      IND 2019-09-02
# 87825    N336  R158  00-03-02      KEW GARDENS         EF      IND 2019-09-04
# 96118   N501A  R020  02-03-00   47-50 STS ROCK       BDFM      IND 2019-09-01
# 105926   N546  R204  00-00-01        CHURCH AV         FG      IND 2019-09-03
# 113904  N702A  R572  01-03-00      96 ST-2 AVE          Q      IND 2019-09-04
# 118600  PTH06  R546  00-00-00  PAVONIA/NEWPORT          1      PTH 2019-09-04
# 123725  PTH18  R549  01-00-08     NEWARK BM BW          1      PTH 2019-09-06
# 129160   R107  R305  00-00-02    WTC-CORTLANDT          1      IRT 2019-09-03
# 154418   R221  R170  01-06-02   14 ST-UNION SQ   456LNQRW      IRT 2019-09-06
# 159699   R240  R047  00-03-03  GRD CNTRL-42 ST      4567S      IRT 2019-09-03
# 168408   R286  R309  00-00-03           176 ST          4      IRT 2019-09-02
# 184105   R513  R093  00-00-01            30 AV        NQW      BMT 2019-09-01
# 190954   R533  R055  00-03-00    FLUSHING-MAIN          7      IRT 2019-09-04
# 195103   R610  R057  00-03-02   ATL AV-BARCLAY  2345BDNQR      IRT 2019-09-04
# 199707   R633  R068  00-00-00    VAN SICLEN AV          3      IRT 2019-09-01
# 204190   S102  R165  00-03-00    TOMPKINSVILLE          1      SRT 2019-09-04
# 6634     A042  R086  01-00-02        PRINCE ST        NRW      BMT 2019-09-03
# 13422    B004  R171  00-00-03             7 AV         BQ      BMT 2019-09-01
# 17305    B024  R211  00-00-03        KINGS HWY         BQ      BMT 2019-09-06
# 24518    D001  R390  01-00-00             8 AV          N      BMT 2019-09-02
# 29246    E014  R374  00-00-03         BAY PKWY          D      BMT 2019-08-31
# 39034    J007  R377  00-06-01      FLUSHING AV         JM      BMT 2019-09-03
# 50894    N057  R188  00-00-01            50 ST         CE      IND 2019-09-04
# 61857    N098  R028  00-02-01        FULTON ST   2345ACJZ      IND 2019-09-04
# 75995    N223  R156  01-05-00  BEDFORD PK BLVD         BD      IND 2019-09-02
# 87824    N336  R158  00-03-02      KEW GARDENS         EF      IND 2019-09-04
# 96117   N501A  R020  02-03-00   47-50 STS ROCK       BDFM      IND 2019-09-01
# 105925   N546  R204  00-00-01        CHURCH AV         FG      IND 2019-09-03
# 113903  N702A  R572  01-03-00      96 ST-2 AVE          Q      IND 2019-09-04
# 118599  PTH06  R546  00-00-00  PAVONIA/NEWPORT          1      PTH 2019-09-04
# 123724  PTH18  R549  01-00-08     NEWARK BM BW          1      PTH 2019-09-06
# 129159   R107  R305  00-00-02    WTC-CORTLANDT          1      IRT 2019-09-03
# 154417   R221  R170  01-06-02   14 ST-UNION SQ   456LNQRW      IRT 2019-09-06
# 159698   R240  R047  00-03-03  GRD CNTRL-42 ST      4567S      IRT 2019-09-03
# 168407   R286  R309  00-00-03           176 ST          4      IRT 2019-09-02
# 184104   R513  R093  00-00-01            30 AV        NQW      BMT 2019-09-01
# 190953   R533  R055  00-03-00    FLUSHING-MAIN          7      IRT 2019-09-04
# 195102   R610  R057  00-03-02   ATL AV-BARCLAY  2345BDNQR      IRT 2019-09-04
# 199706   R633  R068  00-00-00    VAN SICLEN AV          3      IRT 2019-09-01
# 204189   S102  R165  00-03-00    TOMPKINSVILLE          1      SRT 2019-09-04
# 6633     A042  R086  01-00-02        PRINCE ST        NRW      BMT 2019-09-03
# 13421    B004  R171  00-00-03             7 AV         BQ      BMT 2019-09-01
# 17304    B024  R211  00-00-03        KINGS HWY         BQ      BMT 2019-09-06
# 24517    D001  R390  01-00-00             8 AV          N      BMT 2019-09-02
# 29245    E014  R374  00-00-03         BAY PKWY          D      BMT 2019-08-31
# 39033    J007  R377  00-06-01      FLUSHING AV         JM      BMT 2019-09-03
# 50893    N057  R188  00-00-01            50 ST         CE      IND 2019-09-04
# 61856    N098  R028  00-02-01        FULTON ST   2345ACJZ      IND 2019-09-03
# 75994    N223  R156  01-05-00  BEDFORD PK BLVD         BD      IND 2019-09-02
# 87823    N336  R158  00-03-02      KEW GARDENS         EF      IND 2019-09-04
# 96116   N501A  R020  02-03-00   47-50 STS ROCK       BDFM      IND 2019-09-01
# 105924   N546  R204  00-00-01        CHURCH AV         FG      IND 2019-09-03
# 113902  N702A  R572  01-03-00      96 ST-2 AVE          Q      IND 2019-09-04
# 118598  PTH06  R546  00-00-00  PAVONIA/NEWPORT          1      PTH 2019-09-03
# 123723  PTH18  R549  01-00-08     NEWARK BM BW          1      PTH 2019-09-05
# 129158   R107  R305  00-00-02    WTC-CORTLANDT          1      IRT 2019-09-03
# 154416   R221  R170  01-06-02   14 ST-UNION SQ   456LNQRW      IRT 2019-09-06
# 159697   R240  R047  00-03-03  GRD CNTRL-42 ST      4567S      IRT 2019-09-02
# 168406   R286  R309  00-00-03           176 ST          4      IRT 2019-09-02
# 184103   R513  R093  00-00-01            30 AV        NQW      BMT 2019-09-01
# 190952   R533  R055  00-03-00    FLUSHING-MAIN          7      IRT 2019-09-04
# 195101   R610  R057  00-03-02   ATL AV-BARCLAY  2345BDNQR      IRT 2019-09-04
# 199705   R633  R068  00-00-00    VAN SICLEN AV          3      IRT 2019-09-01
# 204188   S102  R165  00-03-00    TOMPKINSVILLE          1      SRT 2019-09-03
# 6632     A042  R086  01-00-02        PRINCE ST        NRW      BMT 2019-09-03
# 13420    B004  R171  00-00-03             7 AV         BQ      BMT 2019-09-01
# 17303    B024  R211  00-00-03        KINGS HWY         BQ      BMT 2019-09-06
# 24516    D001  R390  01-00-00             8 AV          N      BMT 2019-09-02
# 29244    E014  R374  00-00-03         BAY PKWY          D      BMT 2019-08-31
# 39032    J007  R377  00-06-01      FLUSHING AV         JM      BMT 2019-09-03
# 50892    N057  R188  00-00-01            50 ST         CE      IND 2019-09-03
# 61855    N098  R028  00-02-01        FULTON ST   2345ACJZ      IND 2019-09-03
# 75993    N223  R156  01-05-00  BEDFORD PK BLVD         BD      IND 2019-09-02
# 87822    N336  R158  00-03-02      KEW GARDENS         EF      IND 2019-09-03
# 96115   N501A  R020  02-03-00   47-50 STS ROCK       BDFM      IND 2019-08-31
# 105923   N546  R204  00-00-01        CHURCH AV         FG      IND 2019-09-03
# 113901  N702A  R572  01-03-00      96 ST-2 AVE          Q      IND 2019-09-04
# 118597  PTH06  R546  00-00-00  PAVONIA/NEWPORT          1      PTH 2019-09-03
# 123722  PTH18  R549  01-00-08     NEWARK BM BW          1      PTH 2019-09-05
# 129157   R107  R305  00-00-02    WTC-CORTLANDT          1      IRT 2019-09-03
# 154415   R221  R170  01-06-02   14 ST-UNION SQ   456LNQRW      IRT 2019-09-06
# 159696   R240  R047  00-03-03  GRD CNTRL-42 ST      4567S      IRT 2019-09-02
# 168405   R286  R309  00-00-03           176 ST          4      IRT 2019-09-02
#
#             TIME     DESC   ENTRIES     EXITS            DATETIME  \
# 129161  21:00:00  REGULAR    182799     34896 2019-09-03 21:00:00
# 154419  17:00:00  REGULAR    231243    281776 2019-09-06 17:00:00
# 159700  09:00:00  REGULAR    161540    160783 2019-09-03 09:00:00
# 168409  20:00:00  REGULAR   6168926   5195894 2019-09-02 20:00:00
# 184106  16:00:00  REGULAR   1596124  15689018 2019-09-01 16:00:00
# 190955  20:00:00  REGULAR  16110308  14335298 2019-09-04 20:00:00
# 195104  12:00:00  REGULAR  11475697  11337391 2019-09-04 12:00:00
# 199708  20:00:00  REGULAR   6948785   8669550 2019-09-01 20:00:00
# 204191  10:00:00  REGULAR    595574        19 2019-09-04 10:00:00
# 6635    00:00:00  REGULAR   1968978   2428880 2019-09-04 00:00:00
# 13423   21:00:00  REGULAR   4253059   3650710 2019-09-01 21:00:00
# 17306   16:00:00  REGULAR   1610549   3221154 2019-09-06 16:00:00
# 24519   17:00:00  REGULAR     81085     52686 2019-09-02 17:00:00
# 29247   13:00:00  REGULAR  10981271  12406647 2019-08-31 13:00:00
# 39035   13:00:00  REGULAR  10792470  11413441 2019-09-03 13:00:00
# 50895   08:00:00  REGULAR  10170391   3113749 2019-09-04 08:00:00
# 61858   07:00:00  REGULAR     44650     43778 2019-09-04 07:00:00
# 75996   21:00:00  REGULAR    574666     89064 2019-09-02 21:00:00
# 87825   10:30:00  REGULAR   4732451   1640998 2019-09-04 10:30:00
# 204191          38.0         0.0
# 6635           103.0        51.0
# 13423          410.0       292.0
# 17306          335.0       607.0
# 24519          109.0        75.0
# 29247          216.0       155.0
# 39035          114.0        81.0
# 50895          102.0        91.0
# 61858           19.0        78.0
# 75996            0.0         0.0
# 87825         1217.0       241.0
# 96118            3.0        11.0
# 105926         115.0       148.0
# 113904          49.0       186.0
# 118600           0.0         0.0
# 123725          28.0         0.0
# 129160         140.0        31.0
# 154418         245.0       659.0
# 159699           1.0        11.0
# 168408         221.0       165.0
# 184105         215.0       142.0
# 190954         904.0       842.0
# 195103         237.0        76.0
# 199707          98.0       217.0
# 204190           3.0         0.0
# 6634           349.0       224.0
# 13422          457.0       280.0
# 17305          399.0       486.0
# 24518          110.0        69.0
# 29246          152.0        62.0
# 39034          134.0        85.0
# 50894           33.0         3.0
# 61857           83.0        20.0
# 75995            0.0         0.0
# 87824          267.0        30.0
# 96117           11.0         5.0
# 105925         149.0       159.0
# 113903          67.0        85.0
# 118599          63.0        72.0
# 123724          27.0         2.0
# 129159          86.0        24.0
# 154417         113.0       329.0
# 159698          26.0        27.0
# 168407         218.0       123.0
# 184104          38.0        63.0
# 190953        1645.0       666.0
# 195102           7.0        30.0
# 199706         100.0       118.0
# 204189          12.0         0.0
# 6633           174.0       230.0
# 13421          342.0       177.0
# 17304          189.0       197.0
# 24517           24.0        25.0
# 29245            6.0        34.0
# 39033            3.0         7.0
# 50893          252.0        53.0
# 61856          345.0       187.0
# 75994            0.0         0.0
# 87823           47.0        88.0
# 96116           77.0        68.0
# 105924         153.0        56.0
# 113902          65.0        68.0
# 118598        1193.0       305.0
# 123723         105.0         3.0
# 129158          41.0        20.0
# 154416          25.0        31.0
# 159697          40.0        79.0
# 168406         144.0        60.0
# 184103          25.0       169.0
# 190952        1295.0       369.0
# 195101         114.0       111.0
# 199705          58.0        51.0
# 204188          46.0         0.0
# 6632            92.0       321.0
# 13420           75.0        53.0
# 17303            7.0       101.0
# 24516            0.0         6.0
# 29244            nan         nan
# 39032           18.0        35.0
# 50892          632.0       110.0
# 61855          239.0       103.0
# 75993            0.0         0.0
# 87822          238.0       315.0
# 96115           54.0       178.0
# 105923          10.0        32.0
# 113901          78.0        76.0
# 118597         372.0        49.0
# 123722          80.0         3.0
# 129157           2.0         0.0
# 154415         275.0       101.0
# 159696          54.0       135.0
# 168405          17.0        75.0

# %%
df.loc[190950:190960]
# Out:
#          C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 190950  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190951  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190952  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190953  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190954  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190955  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-04
# 190956  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-05
# 190957  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-05
# 190958  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-05
# 190959  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-05
# 190960  R533  R055  00-03-00  FLUSHING-MAIN        7      IRT 2019-09-05
#
#             TIME     DESC   ENTRIES     EXITS            DATETIME  \
# 190950  00:00:00  REGULAR  16105619  14331478 2019-09-04 00:00:00
# 190951  04:00:00  REGULAR  16105675  14331641 2019-09-04 04:00:00
# 190952  08:00:00  REGULAR  16106970  14332010 2019-09-04 08:00:00
# 190953  12:00:00  REGULAR  16108615  14332676 2019-09-04 12:00:00
# 190954  16:00:00  REGULAR  16109519  14333518 2019-09-04 16:00:00
# 190955  20:00:00  REGULAR  16110308  14335298 2019-09-04 20:00:00
# 190956  00:00:00  REGULAR  16110710  14336112 2019-09-05 00:00:00
# 190957  04:00:00  REGULAR  16110765  14336269 2019-09-05 04:00:00
# 190958  08:00:00  REGULAR  16112181  14336560 2019-09-05 08:00:00
# 190959  12:00:00  REGULAR  16113753  14337296 2019-09-05 12:00:00
# 190960  16:00:00  REGULAR  16114585  14338219 2019-09-05 16:00:00
#
#         REAL_ENTRIES  REAL_EXITS
# 190950         381.0       830.0
# 190951          56.0       163.0
# 190952        1295.0       369.0
# 190953        1645.0       666.0
# 190954         904.0       842.0
# 190955         789.0      1780.0
# 190956         402.0       814.0
# 190957          55.0       157.0
# 190958        1416.0       291.0
# 190959        1572.0       736.0
# 190960         832.0       923.0

# %% [markdown]
# Some of the above values being returned by index slicing are actually positive, and not adjacent to any negatives. Not sure why its failing.

# %% [markdown]
# ## RETHINK:
# ### a different way to remove error values
# In order to prevent losing so much data, and unwittingly deleting positive 'good' values as shown immediately above, I'm changing my mind about deleting all 3 rows surrounding a negative value using index slicing.
#
# Instead:
# 1.) delete all negative and NaN values from the data
# 2.) group data by turnstile to find mean entry and exit values
# 3.) to account for those realy high error values caused by negatives: if a given value in the data is greater than 10 times the mean for that turnstile, remove it.

# %%
df = df.loc[df["REAL_ENTRIES"] >= 0]

# %%
df = df.loc[df["REAL_EXITS"] >= 0]

# %%
df.shape
# Out:
# (197503, 14)

# %% [markdown]
# with all negative and NaN values eliminated, we lost (204795 - 197503) = 7292 / 204795 = 3.5% of the data. But 4893 of those were already NaN values so we didn't lose them, we never had them to begin with. 7292 - 4893 = 2399 / 204795 = 1.2% of data eliminated. not bad!

# %% [markdown]
# ## grouping data

# %% [markdown]
# We want to remove entry/exit data which is abnormal *for its specific turnstile/station*. Some values (2000) may be very normal for certain stations, so if we cut off the threshhold above that it would allow 2000 to stay, but if a turnstile's average 4-hour ridership is only 15 people, a value of 2000 should in fact be removed and indicates an error (or, at best, a one-time anomolous event which we don't need to base our average values on anyway). It is for this reason that an arbitrary cut off value should not be chosen for the entire dataset, but rather averages for each turnstile should inform that turstile's individual cutoff value.

# %%
df_turnstile_daily_averages = df.groupby(["STATION", "DATE", "C/A", "UNIT", "SCP"])[["REAL_ENTRIES", "REAL_EXITS"]].median()
df_turnstile_daily_averages
# Out:
#                                          REAL_ENTRIES  REAL_EXITS
# STATION   DATE       C/A  UNIT SCP
# 1 AV      2019-08-31 H007 R248 00-00-00           0.0        10.0
#                                00-00-01           0.0        22.0
#                                00-03-00           0.0         2.0
#                                00-03-01           0.0         0.0
#                                00-03-02           0.0         1.0
# ...                                               ...         ...
# ZEREGA AV 2019-09-06 R419 R326 00-00-01          55.0       118.0
#                                00-03-00         118.0        48.5
#                                00-03-01         185.5        31.5
#                                00-05-00           0.0         0.0
#                                00-05-01           0.0         0.0
#
# [33825 rows x 2 columns]

# %%
max_daily_average_entries = df_turnstile_daily_averages["REAL_ENTRIES"].max()
max_daily_average_entries
# Out:
# 1333.0

# %%
max_daily_average_exits = df_turnstile_daily_averages["REAL_EXITS"].max()
max_daily_average_exits
# Out:
# 2921.5

# %%
df.loc[df["REAL_ENTRIES"] > 3*max_daily_average]
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 73163    N205  R195  02-00-00  161/YANKEE STAD      BD4      IND 2019-09-06
# 116104  PTH03  R552  00-00-00   JOURNAL SQUARE        1      PTH 2019-09-01
# 116877  PTH03  R552  00-01-08   JOURNAL SQUARE        1      PTH 2019-09-03
# 116895  PTH03  R552  00-01-08   JOURNAL SQUARE        1      PTH 2019-09-06
#
#                       TIME     DESC    ENTRIES       EXITS  \
# 73163  2020-07-02 12:22:00  REGULAR  721441289  1895802233
# 116104 2020-07-02 15:50:02  REGULAR     126651      126869
# 116877 2020-07-02 12:39:31  REGULAR       7309        6264
# 116895 2020-07-02 12:03:31  REGULAR       7626        6509
#
#                   DATETIME  REAL_ENTRIES   REAL_EXITS
# 73163  2019-09-06 12:22:00   718560745.0 1886405893.0
# 116104 2019-09-01 15:50:02       92258.0     110916.0
# 116877 2019-09-03 12:39:31        7308.0       6264.0
# 116895 2019-09-06 12:03:31        7625.0       6509.0

# %%
# so at least that pulls the highest, really wrong values explored above, which helps 
# but we know there are more incorrect entries caused by negatives/resets

df_turnstile_daily_averages
# Out:
#                                          REAL_ENTRIES  REAL_EXITS
# STATION   DATE       C/A  UNIT SCP
# 1 AV      2019-08-31 H007 R248 00-00-00           0.0        10.0
#                                00-00-01           0.0        22.0
#                                00-03-00           0.0         2.0
#                                00-03-01           0.0         0.0
#                                00-03-02           0.0         1.0
# ...                                               ...         ...
# ZEREGA AV 2019-09-06 R419 R326 00-00-01          55.0       118.0
#                                00-03-00         118.0        48.5
#                                00-03-01         185.5        31.5
#                                00-05-00           0.0         0.0
#                                00-05-01           0.0         0.0
#
# [33825 rows x 2 columns]

# %%
# using median instead of mean because the super high values will throw off mean more than median
station_averages = df.groupby(["STATION"])[["REAL_ENTRIES", "REAL_EXITS"]].median()

# %%
station_averages.rename(columns={"REAL_ENTRIES":"AVERAGE_ENTRIES"}, inplace=True)

# %%
station_averages.rename(columns={"REAL_EXITS":"AVERAGE_EXITS"}, inplace=True)

# %%
station_averages.reset_index(inplace=True)

# %%
station_averages # average 4-hour ridership for each station
# Out:
#              STATION  AVERAGE_ENTRIES  AVERAGE_EXITS
# 0               1 AV             76.5           82.5
# 1             103 ST            229.0          141.0
# 2      103 ST-CORONA            254.0          168.0
# 3             104 ST             39.5           14.0
# 4             110 ST            144.0          179.0
# ..               ...              ...            ...
# 373         WOODLAWN            162.0           23.0
# 374  WORLD TRADE CTR             69.0           33.0
# 375    WTC-CORTLANDT              6.0            7.0
# 376          YORK ST            455.0          120.0
# 377        ZEREGA AV             13.0           17.5
#
# [378 rows x 3 columns]

# %%
station_std = df.groupby(["STATION"])[["REAL_ENTRIES", "REAL_EXITS"]].std()

# %%
station_std
# Out:
#                  REAL_ENTRIES  REAL_EXITS
# STATION
# 1 AV                    298.4       322.4
# 103 ST                  217.1       182.7
# 103 ST-CORONA           271.2       234.3
# 104 ST                   84.8        42.8
# 110 ST                  218.8       176.1
# ...                       ...         ...
# WOODLAWN                156.8        61.1
# WORLD TRADE CTR         198.7       196.2
# WTC-CORTLANDT           104.6        90.3
# YORK ST                 539.5       441.0
# ZEREGA AV                93.3        86.9
#
# [378 rows x 2 columns]

# %% [markdown]
# trying to add average entries/exits columns to df, applying each average
# to the corresponding station in df, repeated for each entry for that station. hence: merge by common values for station
# ways that have NOT worked to join 2 dataframe this way: df.align, df.merge,
# and the syntax seen below as recommended by Jon the TA.

# %%
# df["AVERAGE_ENTRIES"] = station_averages.loc[station_averages["STATION"] == df["STATION"]]["AVERAGE_ENTRIES"]

# %% [markdown]
# romising route: df.join -> from documentation: "Another way to combine DataFrames is to use columns in each dataset that contain common values (a common unique id). Combining DataFrames using a common field is called “joining”. The columns containing the common values are called “join key(s)”. Joining DataFrames in this way is often useful when one DataFrame is a “lookup table” containing additional data that we want to include in the other." Perfect!
#
# update (lol) the pd.join() method for inner joins is actually pd.merge().

# %%
df_copy_f = df
df_with_averages = pd.merge(left=df_copy_f, right=station_averages, left_on="STATION", right_on="STATION")

# %%
df_with_averages
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# ...       ...   ...       ...            ...      ...      ...        ...
# 197498  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197499  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197500  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197501  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197502  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
#
#                       TIME     DESC  ENTRIES    EXITS            DATETIME  \
# 0      2020-07-02 04:00:00  REGULAR  7183258  2433149 2019-08-31 04:00:00
# 1      2020-07-02 08:00:00  REGULAR  7183278  2433176 2019-08-31 08:00:00
# 2      2020-07-02 12:00:00  REGULAR  7183393  2433262 2019-08-31 12:00:00
# 3      2020-07-02 16:00:00  REGULAR  7183572  2433312 2019-08-31 16:00:00
# 4      2020-07-02 20:00:00  REGULAR  7183842  2433348 2019-08-31 20:00:00
# ...                    ...      ...      ...      ...                 ...
# 197498 2020-07-02 05:00:00  REGULAR     5554      420 2019-09-06 05:00:00
# 197499 2020-07-02 09:00:00  REGULAR     5554      420 2019-09-06 09:00:00
# 197500 2020-07-02 13:00:00  REGULAR     5554      420 2019-09-06 13:00:00
# 197501 2020-07-02 17:00:00  REGULAR     5554      420 2019-09-06 17:00:00
# 197502 2020-07-02 21:00:00  REGULAR     5554      420 2019-09-06 21:00:00
#
#         REAL_ENTRIES  REAL_EXITS  AVERAGE_ENTRIES  AVERAGE_EXITS
# 0               16.0         7.0             71.0           62.0
# 1               20.0        27.0             71.0           62.0
# 2              115.0        86.0             71.0           62.0
# 3              179.0        50.0             71.0           62.0
# 4              270.0        36.0             71.0           62.0
# ...              ...         ...              ...            ...
# 197498           0.0         0.0             18.0            1.0
# 197499           0.0         0.0             18.0            1.0
# 197500           0.0         0.0             18.0            1.0
# 197501           0.0         0.0             18.0            1.0
# 197502           0.0         0.0             18.0            1.0
#
# [197503 rows x 16 columns]

# %%
# filtering out any single 4-hour entry with ridership more than 100 times
# greater than the stations total average ridership. will remove error values and also
# even if it removes a real value, if there was a surge of 2 orders of magnitude it is 
# probably a standalone event that doesn't help inform our data.

df_filtered_entries = df_with_averages.loc[df_with_averages["REAL_ENTRIES"] < 100*df_with_averages["AVERAGE_ENTRIES"]]

# %%
df_filtered_entries
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# ...       ...   ...       ...            ...      ...      ...        ...
# 197498  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197499  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197500  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197501  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197502  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
#
#                       TIME     DESC  ENTRIES    EXITS            DATETIME  \
# 0      2020-07-02 04:00:00  REGULAR  7183258  2433149 2019-08-31 04:00:00
# 1      2020-07-02 08:00:00  REGULAR  7183278  2433176 2019-08-31 08:00:00
# 2      2020-07-02 12:00:00  REGULAR  7183393  2433262 2019-08-31 12:00:00
# 3      2020-07-02 16:00:00  REGULAR  7183572  2433312 2019-08-31 16:00:00
# 4      2020-07-02 20:00:00  REGULAR  7183842  2433348 2019-08-31 20:00:00
# ...                    ...      ...      ...      ...                 ...
# 197498 2020-07-02 05:00:00  REGULAR     5554      420 2019-09-06 05:00:00
# 197499 2020-07-02 09:00:00  REGULAR     5554      420 2019-09-06 09:00:00
# 197500 2020-07-02 13:00:00  REGULAR     5554      420 2019-09-06 13:00:00
# 197501 2020-07-02 17:00:00  REGULAR     5554      420 2019-09-06 17:00:00
# 197502 2020-07-02 21:00:00  REGULAR     5554      420 2019-09-06 21:00:00
#
#         REAL_ENTRIES  REAL_EXITS  AVERAGE_ENTRIES  AVERAGE_EXITS
# 0               16.0         7.0             71.0           62.0
# 1               20.0        27.0             71.0           62.0
# 2              115.0        86.0             71.0           62.0
# 3              179.0        50.0             71.0           62.0
# 4              270.0        36.0             71.0           62.0
# ...              ...         ...              ...            ...
# 197498           0.0         0.0             18.0            1.0
# 197499           0.0         0.0             18.0            1.0
# 197500           0.0         0.0             18.0            1.0
# 197501           0.0         0.0             18.0            1.0
# 197502           0.0         0.0             18.0            1.0
#
# [194464 rows x 16 columns]

# %%
# now similarly filtering for exits with higher than average values 
# from the already entry-filtered data

df_filtered = df_filtered_entries.loc[df_filtered_entries["REAL_EXITS"] < 100*df_filtered_entries["AVERAGE_EXITS"]]

# %%
df_filtered
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2019-08-31
# ...       ...   ...       ...            ...      ...      ...        ...
# 197498  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197499  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197500  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197501  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
# 197502  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2019-09-06
#
#                       TIME     DESC  ENTRIES    EXITS            DATETIME  \
# 0      2020-07-02 04:00:00  REGULAR  7183258  2433149 2019-08-31 04:00:00
# 1      2020-07-02 08:00:00  REGULAR  7183278  2433176 2019-08-31 08:00:00
# 2      2020-07-02 12:00:00  REGULAR  7183393  2433262 2019-08-31 12:00:00
# 3      2020-07-02 16:00:00  REGULAR  7183572  2433312 2019-08-31 16:00:00
# 4      2020-07-02 20:00:00  REGULAR  7183842  2433348 2019-08-31 20:00:00
# ...                    ...      ...      ...      ...                 ...
# 197498 2020-07-02 05:00:00  REGULAR     5554      420 2019-09-06 05:00:00
# 197499 2020-07-02 09:00:00  REGULAR     5554      420 2019-09-06 09:00:00
# 197500 2020-07-02 13:00:00  REGULAR     5554      420 2019-09-06 13:00:00
# 197501 2020-07-02 17:00:00  REGULAR     5554      420 2019-09-06 17:00:00
# 197502 2020-07-02 21:00:00  REGULAR     5554      420 2019-09-06 21:00:00
#
#         REAL_ENTRIES  REAL_EXITS  AVERAGE_ENTRIES  AVERAGE_EXITS
# 0               16.0         7.0             71.0           62.0
# 1               20.0        27.0             71.0           62.0
# 2              115.0        86.0             71.0           62.0
# 3              179.0        50.0             71.0           62.0
# 4              270.0        36.0             71.0           62.0
# ...              ...         ...              ...            ...
# 197498           0.0         0.0             18.0            1.0
# 197499           0.0         0.0             18.0            1.0
# 197500           0.0         0.0             18.0            1.0
# 197501           0.0         0.0             18.0            1.0
# 197502           0.0         0.0             18.0            1.0
#
# [192344 rows x 16 columns]

# %%
# reassigning the "df" name to this new filtered column since I feel good about it!

# %% [markdown]
# # here down: at least removing the very worst wrong values for now, just to move forward with visualization
# ## come back and remove other bad values later! (update: done! see above)
# ### so far: negatives, NaNs, and the top 5 hugest error values have been removed

# %% [markdown]
# for now: removing highest error values -- those where the 4-hour period
# number of entries is more than 3 times greater the max daily average riders
# across all of NYC. As demonstrated above, the stations it pulls out for greatest
# erroneous entries are the same as those when filtered for exits, so doing just
# one will suffice.

# %%
df_copy = df.loc[df["REAL_ENTRIES"] < 3*max_daily_average_entries]
df_copy["REAL_ENTRIES"].sort_values(ascending=False)
# Out:
# 3095     2872.0
# 3089     2746.0
# 3101     2719.0
# 96607    2599.0
# 3173     2598.0
#           ...
# 124881      0.0
# 124882      0.0
# 124883      0.0
# 124884      0.0
# 204794      0.0
# Name: REAL_ENTRIES, Length: 197499, dtype: float64

# %%
df_traffic_by_day = df_copy.groupby(["STATION", "DATE"])[["REAL_ENTRIES", "REAL_EXITS"]].sum()

# %%
df_traffic_by_day.head(100)
# Out:
#                             REAL_ENTRIES  REAL_EXITS
# STATION         DATE
# 1 AV            2019-08-31        4011.0      5782.0
#                 2019-09-01        4282.0      6209.0
#                 2019-09-02        3733.0      6373.0
#                 2019-09-03       14574.0     16430.0
#                 2019-09-04       16428.0     17988.0
#                 2019-09-05       18734.0     20107.0
#                 2019-09-06       19451.0     21978.0
# 103 ST          2019-08-31       14793.0     10702.0
#                 2019-09-01       14661.0     12091.0
#                 2019-09-02       13929.0     11761.0
#                 2019-09-03       27704.0     20126.0
#                 2019-09-04       29168.0     21162.0
#                 2019-09-05       31235.0     22208.0
#                 2019-09-06       31048.0     22556.0
# 103 ST-CORONA   2019-08-31       12951.0      9052.0
#                 2019-09-01       11365.0     10136.0
#                 2019-09-02       11000.0      9110.0
#                 2019-09-03       19668.0     13612.0
#                 2019-09-04       20260.0     15588.0
#                 2019-09-05       20597.0     15286.0
#                 2019-09-06       20894.0     15612.0
# 104 ST          2019-08-31        1542.0       566.0
#                 2019-09-01        1396.0       603.0
#                 2019-09-02        1321.0       636.0
#                 2019-09-03        3262.0      1235.0
#                 2019-09-04        3323.0      1445.0
#                 2019-09-05        3398.0      1382.0
#                 2019-09-06        3400.0      1507.0
# 110 ST          2019-08-31        5522.0      4865.0
#                 2019-09-01        5178.0      5338.0
#                 2019-09-02        4832.0      4929.0
#                 2019-09-03        9460.0      8441.0
#                 2019-09-04       10085.0      9405.0
#                 2019-09-05       11238.0     10225.0
#                 2019-09-06       11354.0     10424.0
# 111 ST          2019-08-31        9736.0      5554.0
#                 2019-09-01        8437.0      6227.0
#                 2019-09-02        8270.0      5650.0
#                 2019-09-03       15489.0      8723.0
#                 2019-09-04       16259.0      9738.0
#                 2019-09-05       16738.0      9981.0
#                 2019-09-06       16665.0      9939.0
# 116 ST          2019-08-31       17569.0     11384.0
#                 2019-09-01       17424.0     12665.0
#                 2019-09-02       15188.0     11028.0
#                 2019-09-03       29847.0     18353.0
#                 2019-09-04       30971.0     18892.0
#                 2019-09-05       33117.0     19773.0
#                 2019-09-06       33349.0     20050.0
# 116 ST-COLUMBIA 2019-08-31        6159.0      2553.0
#                 2019-09-01        7444.0      3598.0
#                 2019-09-02        5795.0      3055.0
#                 2019-09-03       14976.0      8514.0
#                 2019-09-04       16559.0      8459.0
#                 2019-09-05       17459.0      8702.0
#                 2019-09-06       16951.0      7408.0
# 121 ST          2019-08-31        1118.0       763.0
#                 2019-09-01        1074.0       742.0
#                 2019-09-02        1090.0       797.0
#                 2019-09-03        2305.0      1458.0
#                 2019-09-04        2321.0      1559.0
#                 2019-09-05        2391.0      1555.0
#                 2019-09-06        2292.0      1550.0
# 125 ST          2019-08-31       39984.0     40097.0
#                 2019-09-01       47741.0     41065.0
#                 2019-09-02       41062.0     31451.0
#                 2019-09-03       72636.0     60397.0
#                 2019-09-04       76352.0     64684.0
#                 2019-09-05       79672.0     66735.0
#                 2019-09-06       79342.0     65417.0
# 135 ST          2019-08-31        9140.0      4126.0
#                 2019-09-01        8875.0      4985.0
#                 2019-09-02        8227.0      4622.0
#                 2019-09-03       17970.0      8170.0
#                 2019-09-04       19230.0      8918.0
#                 2019-09-05       20407.0      9395.0
#                 2019-09-06       19844.0      9107.0
# 137 ST CITY COL 2019-08-31        6496.0      4772.0
#                 2019-09-01        6236.0      6014.0
#                 2019-09-02        5902.0      5857.0
#                 2019-09-03       13029.0     11770.0
#                 2019-09-04       13564.0     12374.0
#                 2019-09-05       14185.0     12799.0
#                 2019-09-06       13159.0     11664.0
# 138/GRAND CONC  2019-08-31        1722.0      1501.0
#                 2019-09-01        1491.0      1377.0
#                 2019-09-02        1473.0      1400.0
#                 2019-09-03        3584.0      3172.0
#                 2019-09-04        3768.0      3295.0
#                 2019-09-05        3796.0      3262.0
#                 2019-09-06        3627.0      3266.0
# 14 ST           2019-08-31       23268.0     26640.0
#                 2019-09-01       26792.0     27518.0
#                 2019-09-02       22899.0     24215.0
#                 2019-09-03       50006.0     47316.0
#                 2019-09-04       56871.0     51157.0
#                 2019-09-05       60943.0     54138.0
#                 2019-09-06       61839.0     54135.0
# 14 ST-UNION SQ  2019-08-31       48790.0     55241.0
#                 2019-09-01       49647.0     51953.0

# %%
df_traffic_by_day.reset_index(inplace=True)
df_traffic_by_day
# Out:
#       index    STATION       DATE  REAL_ENTRIES  REAL_EXITS
# 0         0       1 AV 2019-08-31        4011.0      5782.0
# 1         1       1 AV 2019-09-01        4282.0      6209.0
# 2         2       1 AV 2019-09-02        3733.0      6373.0
# 3         3       1 AV 2019-09-03       14574.0     16430.0
# 4         4       1 AV 2019-09-04       16428.0     17988.0
# ...     ...        ...        ...           ...         ...
# 2641   2641  ZEREGA AV 2019-09-02         565.0       941.0
# 2642   2642  ZEREGA AV 2019-09-03        2635.0      2497.0
# 2643   2643  ZEREGA AV 2019-09-04        2683.0      2601.0
# 2644   2644  ZEREGA AV 2019-09-05        2980.0      2813.0
# 2645   2645  ZEREGA AV 2019-09-06        2864.0      2559.0
#
# [2646 rows x 5 columns]

# %%
df_total_station_traffic = df_copy.groupby(["STATION"])[["REAL_ENTRIES", "REAL_EXITS"]].sum()

# %%
df_total_station_traffic
# Out:
#                  REAL_ENTRIES  REAL_EXITS
# STATION
# 1 AV                  81213.0     94867.0
# 103 ST               162538.0    120606.0
# 103 ST-CORONA        116735.0     88396.0
# 104 ST                17642.0      7374.0
# 110 ST                57669.0     53627.0
# ...                       ...         ...
# WOODLAWN              39972.0      9913.0
# WORLD TRADE CTR       98169.0     78263.0
# WTC-CORTLANDT         76076.0     63236.0
# YORK ST               72108.0     39155.0
# ZEREGA AV             12951.0     13474.0
#
# [378 rows x 2 columns]

# %%
df_total_station_traffic["REAL_ENTRIES"].sort_values( ascending=False).head(20)
# Out:
# STATION
# 34 ST-PENN STA    872913.0
# GRD CNTRL-42 ST   718276.0
# 34 ST-HERALD SQ   631632.0
# 23 ST             588340.0
# 14 ST-UNION SQ    539177.0
# TIMES SQ-42 ST    530203.0
# FULTON ST         514201.0
# 42 ST-PORT AUTH   497579.0
# 86 ST             449433.0
# 125 ST            436789.0
# CANAL ST          397331.0
# 59 ST COLUMBUS    394153.0
# FLUSHING-MAIN     342556.0
# 96 ST             328399.0
# 59 ST             313300.0
# 14 ST             302618.0
# CHAMBERS ST       298116.0
# 47-50 STS ROCK    292175.0
# PATH NEW WTC      285051.0
# JKSN HT-ROOSVLT   284638.0
# Name: REAL_ENTRIES, dtype: float64

# %% [markdown]
# Verifying the top busiest stations against actual busiest stations in 2019 (below) to verify accuracy of our filtered data, our data analysis has proved correct! 9 out of 10 of the year's busiest are in our list, and this is only for one week's worth of data which may have discrepencies. Excellent! Now we can move forward with further analysis after confirming the accuracy of how we've handled the data thus far.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_copy.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-08-31
#
#                  TIME     DESC  ENTRIES    EXITS            DATETIME  \
# 1 2020-07-02 04:00:00  REGULAR  7183258  2433149 2019-08-31 04:00:00
# 2 2020-07-02 08:00:00  REGULAR  7183278  2433176 2019-08-31 08:00:00
# 3 2020-07-02 12:00:00  REGULAR  7183393  2433262 2019-08-31 12:00:00
# 4 2020-07-02 16:00:00  REGULAR  7183572  2433312 2019-08-31 16:00:00
# 5 2020-07-02 20:00:00  REGULAR  7183842  2433348 2019-08-31 20:00:00
#
#    REAL_ENTRIES  REAL_EXITS
# 1          16.0         7.0
# 2          20.0        27.0
# 3         115.0        86.0
# 4         179.0        50.0
# 5         270.0        36.0

# %%
df_traffic_by_day.head()
# Out:
#    index STATION       DATE  REAL_ENTRIES  REAL_EXITS
# 0      0    1 AV 2019-08-31        4011.0      5782.0
# 1      1    1 AV 2019-09-01        4282.0      6209.0
# 2      2    1 AV 2019-09-02        3733.0      6373.0
# 3      3    1 AV 2019-09-03       14574.0     16430.0
# 4      4    1 AV 2019-09-04       16428.0     17988.0

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# # RERUNNING all of the above with fully and correctly filtered data!!! yay!

# %%
df_traffic_by_day_f = df_filtered.groupby(["STATION", "DATE"])[["REAL_ENTRIES", "REAL_EXITS"]].sum()

# %%
df_traffic_by_day_f.reset_index(inplace=True)

# %%
df_total_station_traffic_f = df_filtered.groupby(["STATION"])[["REAL_ENTRIES", "REAL_EXITS"]].sum()

# %%
busiest_stations = df_total_station_traffic_f["REAL_ENTRIES"].sort_values(ascending=False).head(20)
busiest_stations
# Out:
# STATION
# 34 ST-PENN STA    872913.0
# GRD CNTRL-42 ST   718276.0
# 34 ST-HERALD SQ   631632.0
# 23 ST             588340.0
# 14 ST-UNION SQ    539177.0
# TIMES SQ-42 ST    530203.0
# FULTON ST         514201.0
# 42 ST-PORT AUTH   497579.0
# 86 ST             449433.0
# 125 ST            436789.0
# CANAL ST          397331.0
# 59 ST COLUMBUS    394153.0
# FLUSHING-MAIN     342556.0
# 96 ST             328399.0
# 59 ST             313300.0
# 14 ST             302618.0
# CHAMBERS ST       298116.0
# 47-50 STS ROCK    292175.0
# PATH NEW WTC      285051.0
# JKSN HT-ROOSVLT   284638.0
# Name: REAL_ENTRIES, dtype: float64

# %% [markdown]
# Still accurate. :) in fact more accurate, and scalable

# %%
df_total_station_traffic_f.reset_index(inplace=True)

# %%
plt.figure(figsize=[10,100])
plt.barh(df_total_station_traffic["STATION"], df_total_station_traffic["REAL_ENTRIES"])
# Out:
# <BarContainer object of 378 artists>

# %% [markdown]
# # TO DO:
# ### 1.) combine exits and entries into 'traffic'
# ### 2.) scale to all data (3 months)
# ### 3.) read in and analyze school data
# ### 4.) find worst schools and closest stations
# ### 5.) switch to weekdays only
# ### 6.) find afternoons only

# %% [markdown]
# # analyzing data

# %% [markdown]
# SO, now, finally, with clean and accurate data, we can analyze it to pull results that we want for the client -- stations where they should set up STEM outreach demos near busy stations closest underachieving schools to reach the most needy students during their communte home from school, and inspire them about STEM.
#
# First off, students will only be commuting during the day, so we can drop weekend data.

# %%
df["DATE"].describe()
# Out:
# count                  197503
# unique                      7
# top       2019-09-04 00:00:00
# freq                    29014
# first     2019-08-31 00:00:00
# last      2019-09-06 00:00:00
# Name: DATE, dtype: object

# %%
df_filtered["DAY"] = df_filtered.loc[df_filtered["DATE"]].dt.dayofweek
# Out:
# ------------------------------------------------------------------
# KeyError                         Traceback (most recent call last)
# <ipython-input-394-199145de677a> in <module>
# ----> 1 df_filtered["DAY"] = df_filtered.loc[df_filtered["DATE"]].dt.dayofweek
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [DatetimeIndex(['2019-08-31', '2019-08-31', '2019-08-31', '2019-08-31',\n               '2019-08-31', '2019-09-01', '2019-09-01', '2019-09-01',\n               '2019-09-01', '2019-09-01',\n               ...\n               '2019-09-05', '2019-09-05', '2019-09-05', '2019-09-05',\n               '2019-09-06', '2019-09-06', '2019-09-06', '2019-09-06',\n               '2019-09-06', '2019-09-06'],\n              dtype='datetime64[ns]', length=192344, freq=None)] are in the [index]"
